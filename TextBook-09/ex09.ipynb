# %% [markdown]
# ###
# ### 그래프 공통
# ###

# %%
import pandas as pd	
import matplotlib.pyplot as plt
import seaborn as sns


# GitHub의 CSV 파일을 불러오기
titanic_df = pd.read_csv('https://raw.githubusercontent.com/YangGuiBee/ML/main/TextBook-09/titanic_train.csv')

# %% [markdown]
# ### 1. 선 그래프 (Line Plot) Matplotlib

# %%
plt.figure(figsize=(8, 6))
plt.plot(titanic_df['PassengerId'], titanic_df['Fare'])
plt.title('Passenger ID vs Fare')
plt.xlabel('Passenger ID')
plt.ylabel('Fare')
plt.show()

# %% [markdown]
# ### 1. 선 그래프 (Line Plot) seaborn+Matplotlib

# %%
plt.figure(figsize=(8, 6))
sns.lineplot(x='PassengerId', y='Fare', data=titanic_df)
plt.title('Passenger ID vs Fare')
plt.show()

# %% [markdown]
# ### 1. 선 그래프 (Line Plot) seaborn

# %%
sns.set(rc={'figure.figsize':(8, 6)}) 

sns.lineplot(x='PassengerId', y='Fare', data=titanic_df).set(title='Passenger ID vs Fare')
# Out:
# [Text(0.5, 1.0, 'Passenger ID vs Fare')]

# %% [markdown]
# ### 2. 산점도(Scatter Plot) Matplotlib

# %%
plt.figure(figsize=(8, 6))
plt.scatter(titanic_df['Age'], titanic_df['Fare'])
plt.title('Age vs Fare')
plt.xlabel('Age')
plt.ylabel('Fare')
plt.show()

# %% [markdown]
# ### 2. 산점도(Scatter Plot) seaborn+Matplotlib

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x='Age', y='Fare', data=titanic_df)
plt.title('Age vs Fare')
plt.show()

# %% [markdown]
# ### 2. 산점도(Scatter Plot) seaborn

# %%
import seaborn as sns

# Seaborn 스타일 및 크기 설정
sns.set(rc={'figure.figsize':(8, 6)})

# 그래프 생성
sns.scatterplot(x='Age', y='Fare', data=titanic_df).set(title='Age vs Fare')
# Out:
# [Text(0.5, 1.0, 'Age vs Fare')]

# %% [markdown]
# ### 3. 막대 그래프(Bar Plot) Matplotlib

# %%
titanic_df.groupby('Pclass')['Fare'].mean().plot(kind='bar')
plt.title('Average Fare by Class')
plt.xlabel('Class')
plt.ylabel('Average Fare')
plt.show()

# %% [markdown]
# ### 3. 막대 그래프(Bar Plot) seaborn+Matplotlib

# %%
plt.figure(figsize=(8, 6))
sns.barplot(x='Pclass', y='Fare', data=titanic_df)
plt.title('Average Fare by Class')
plt.show()

# %% [markdown]
# ### 3. 막대 그래프(Bar Plot) seaborn

# %%
sns.set(rc={'figure.figsize':(8, 6)})

sns.barplot(x='Pclass', y='Fare', data=titanic_df).set(title='Average Fare by Class')
# Out:
# [Text(0.5, 1.0, 'Average Fare by Class')]

# %% [markdown]
# ### 4. 히스토그램(Histogram) Matplotlib

# %%
plt.figure(figsize=(8, 6))
plt.hist(titanic_df['Age'], bins=20)
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ### 4. 히스토그램(Histogram) seaborn+Matplotlib

# %%
plt.figure(figsize=(8, 6))
sns.histplot(titanic_df['Age'], bins=20)
plt.title('Age Distribution')
plt.show()

# %% [markdown]
# ### 4. 히스토그램(Histogram) seaborn

# %%
sns.set(rc={'figure.figsize':(8, 6)})

sns.histplot(titanic_df['Age'], bins=20).set(title='Age Distribution')
# Out:
# [Text(0.5, 1.0, 'Age Distribution')]

# %% [markdown]
# ### 5. 박스 플롯(Box Plot) Matplotlib

# %%
plt.figure(figsize=(8, 6))
plt.boxplot([titanic_df[titanic_df['Pclass'] == i]['Fare'] for i in range(1, 4)])
plt.title('Fare Distribution by Class')
plt.xlabel('Class')
plt.ylabel('Fare')
plt.xticks([1, 2, 3], ['1st Class', '2nd Class', '3rd Class'])
plt.show()

# %% [markdown]
# ### 5. 박스 플롯(Box Plot) seaborn+Matplotlib

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x='Pclass', y='Fare', data=titanic_df)
plt.title('Fare Distribution by Class')
plt.show()

# %% [markdown]
# ### 5. 박스 플롯(Box Plot) seaborn

# %%
sns.set(rc={'figure.figsize':(8, 6)})

sns.boxplot(x='Pclass', y='Fare', data=titanic_df).set(title='Fare Distribution by Class')
# Out:
# [Text(0.5, 1.0, 'Fare Distribution by Class')]

# %% [markdown]
# ### 6. 파이 차트(Pie Chart) Matplotlib

# %%
plt.figure(figsize=(6, 6))
titanic_df['Survived'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title('Survival Rate')
plt.ylabel('')
plt.show()

# %% [markdown]
# ### 7. 히트맵(Heatmap) seaborn+Matplotlib

# %%
# 상관 관계에 사용할 숫자형 열을 명시적으로 선택 (예: 생존 여부, 클래스, 나이, 형제/배우자 수, 부모/자녀 수, 요금)
numeric_cols = titanic_df[['Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare']]

# 결측값 처리 (Age 등의 열에 결측값이 있으므로 이를 0으로 채움)
numeric_cols = numeric_cols.fillna(0)

# 상관 관계 계산
corr = numeric_cols.corr()

# 상관 관계 히트맵 그리기
plt.figure(figsize=(8, 6))
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# ### 7. 히트맵(Heatmap) seaborn

# %%
# Numeric columns 선택 및 결측치 처리
numeric_cols = titanic_df[['Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare']].fillna(0)

# 상관 행렬 계산
corr = numeric_cols.corr()

# Seaborn 스타일 및 크기 설정
sns.set(rc={'figure.figsize':(8, 6)})

# 히트맵 생성
sns.heatmap(corr, annot=True, cmap='coolwarm').set(title='Correlation Heatmap')
# Out:
# [Text(0.5, 1.0, 'Correlation Heatmap')]

# %% [markdown]
# ### 8. 누적 막대 그래프(Stacked Bar Plot) Matplotlib

# %%
survived = titanic_df[titanic_df['Survived'] == 1]['Pclass'].value_counts().sort_index()
not_survived = titanic_df[titanic_df['Survived'] == 0]['Pclass'].value_counts().sort_index()
plt.figure(figsize=(8, 6))
plt.bar(survived.index, survived, label='Survived')
plt.bar(not_survived.index, not_survived, bottom=survived, label='Not Survived')
plt.title('Survival by Class')
plt.xlabel('Pclass')
plt.ylabel('Count')
plt.legend()
plt.show()

# %% [markdown]
# ### 9. 면적 그래프(Area Plot) Matplotlib

# %%
plt.figure(figsize=(8, 6))
plt.fill_between(titanic_df['PassengerId'], titanic_df['Fare'], color="skyblue", alpha=0.4)
plt.title('Fare Area Plot')
plt.xlabel('Passenger ID')
plt.ylabel('Fare')
plt.show()

# %% [markdown]
# ### 10. 꺾은선 그래프(Step Plot) Matplotlib

# %%
plt.figure(figsize=(8, 6))
plt.step(titanic_df['Fare'].sort_values(), range(len(titanic_df)), where='mid')
plt.title('Fare Step Plot')
plt.xlabel('Fare')
plt.ylabel('Cumulative Count')
plt.show()

# %% [markdown]
# ### 11. 버블 차트(Bubble Plot) Matplotlib

# %%
plt.figure(figsize=(8, 6))
plt.scatter(titanic_df['Age'], titanic_df['Fare'], s=titanic_df['Survived'] * 100, alpha=0.5)
plt.title('Age vs Fare (Bubble size represents Survival)')
plt.xlabel('Age')
plt.ylabel('Fare')
plt.show()

# %% [markdown]
# ### 11. 버블 차트(Bubble Plot) 추가 Matplotlib

# %%
plt.figure(figsize=(10, 8))

# Fare 값을 기본으로 하되, 생존한 승객(Survived=1)의 경우 크기를 더 크게 함
bubble_size = (titanic_df['Fare'] + 1) * (titanic_df['Survived'] + 1) * 2  # 스케일링을 2배로 축소

plt.scatter(titanic_df['Age'], titanic_df['Fare'], 
            s=bubble_size,  # 크기를 Fare와 Survived로 설정
            alpha=0.5)
plt.title('Age vs Fare (Bubble size represents Fare and Survival)')
plt.xlabel('Age')
plt.ylabel('Fare')
plt.show()

# %% [markdown]
# ### 12. 도넛 차트(Donut Chart) Matplotlib

# %%
plt.figure(figsize=(6, 6))
titanic_df['Survived'].value_counts().plot(kind='pie', autopct='%1.1f%%', wedgeprops={'width': 0.3})
plt.title('Survival Distribution (Donut Chart)')
plt.ylabel('')
plt.show()

# %% [markdown]
# ### 13. 바이올린 플롯(Violin Plot) seaborn+Matplotlib

# %%
plt.figure(figsize=(8, 6))
sns.violinplot(x='Pclass', y='Fare', data=titanic_df)
plt.title('Fare Distribution by Class (Violin Plot)')
plt.xlabel('Pclass')
plt.ylabel('Fare')
plt.show()

# %% [markdown]
# ### 13. 바이올린 플롯(Violin Plot) seaborn

# %%
sns.set(rc={'figure.figsize':(8, 6)})

sns.violinplot(x='Pclass', y='Fare', data=titanic_df).set(
    title='Fare Distribution by Class (Violin Plot)', xlabel='Pclass', ylabel='Fare'
)
# Out:
# [Text(0.5, 1.0, 'Fare Distribution by Class (Violin Plot)'),
#  Text(0.5, 0, 'Pclass'),
#  Text(0, 0.5, 'Fare')]

# %% [markdown]
# ### 14. 밀도 플롯(Kernel Density Estimate, KDE) seaborn+Matplotlib

# %%
plt.figure(figsize=(8, 6))
sns.kdeplot(titanic_df['Fare'], fill=True)
plt.title('Fare Density Plot')
plt.xlabel('Fare')
plt.show()

# %% [markdown]
# ### 14. 밀도 플롯(Kernel Density Estimate, KDE) seaborn

# %%
sns.set(rc={'figure.figsize':(8, 6)})

sns.kdeplot(titanic_df['Fare'], fill=True).set(
    	title='Fare Density Plot', xlabel='Fare')
# Out:
# [Text(0.5, 1.0, 'Fare Density Plot'), Text(0.5, 0, 'Fare')]

# %% [markdown]
# ### 15. 타임 시리즈(Time Series Plot) Matplotlib

# %%
# 가상의 날짜 열 추가 (예: '1912-01-01'부터 시작하여 승객 ID 순서대로 하루씩 증가)
titanic_df['Date'] = pd.date_range(start='1912-01-01', periods=len(titanic_df), freq='D')

plt.figure(figsize=(10, 6))
plt.plot(titanic_df['Date'], titanic_df['Fare'])
plt.title('Fare over Time (Synthetic Date)')
plt.xlabel('Date')
plt.ylabel('Fare')
plt.xticks(rotation=45)  # x축 라벨 회전
plt.show()

# %% [markdown]
# ### 15. 타임 시리즈(Time Series Plot) seaborn+Matplotlib

# %%
plt.figure(figsize=(8, 6))
sns.lineplot(x='PassengerId', y='Fare', data=titanic_df)
plt.title('Fare over Passenger ID')
plt.show()

# %% [markdown]
# ### 15. 타임 시리즈(Time Series Plot) seaborn

# %%
sns.set(rc={'figure.figsize':(10, 6)})
plot = sns.lineplot(x='Date', y='Fare', data=titanic_df)
plot.set(title='Fare over Time (Synthetic Date)', xlabel='Date', ylabel='Fare')
plot.set_xticklabels(plot.get_xticklabels(), rotation=45)
# Out:
# C:\Users\guibe\AppData\Local\Temp\ipykernel_18632\819195404.py:4: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   plot.set_xticklabels(plot.get_xticklabels(), rotation=45)
# [Text(-21185.0, 0, '1912-01'),
#  Text(-21094.0, 0, '1912-04'),
#  Text(-21003.0, 0, '1912-07'),
#  Text(-20911.0, 0, '1912-10'),
#  Text(-20819.0, 0, '1913-01'),
#  Text(-20729.0, 0, '1913-04'),
#  Text(-20638.0, 0, '1913-07'),
#  Text(-20546.0, 0, '1913-10'),
#  Text(-20454.0, 0, '1914-01'),
#  Text(-20364.0, 0, '1914-04'),
#  Text(-20273.0, 0, '1914-07')]

# %% [markdown]
# ### 16. 3D 그래프(3D Plot) Matplotlib

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(titanic_df['Age'], titanic_df['Fare'], titanic_df['Survived'], c=titanic_df['Survived'], cmap='coolwarm')
ax.set_xlabel('Age')
ax.set_ylabel('Fare')
ax.set_zlabel('Survived')
plt.title('3D Scatter Plot (Age, Fare, Survival)')
plt.show()
